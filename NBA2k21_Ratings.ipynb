# %%
import pandas as pd
import requests
import seaborn as sns
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup

# %%
# Initial Scrape

url = 'https://nba2kw.com/list/nba-2k-ratings-top-100-players/'
req = requests.get(url)

data = req.text
soup = BeautifulSoup(req.content, 'lxml')

# %%
# Create and inspect DataFrame

table = soup.find_all('table')
rank = pd.read_html(str(table))[0]

display(rank)
# Out:
#     Rank                 Player       Team Pos.  OVR Height  \
# 0      1           LeBron James     Lakers   SF   97   6'9"
# 1      2            Steph Curry   Warriors   PG   96   6'3"
# 2      3          Kawhi Leonard   Clippers   SF   96   6'7"
# 3      4  Giannis Antetokounmpo      Bucks   PF   96  6'11"
# 4      5           Kevin Durant       Nets   SF   96   6'10
# ..   ...                    ...        ...  ...  ...    ...
# 95    96           Steven Adams   Pelicans    C   80  6'11"
# 96    97            Enes Kanter    Celtics    C   80  6'10"
# 97    98         Thaddeus Young      Bulls   PF   80   6'8"
# 98    99          Kyle Anderson  Grizzlies   SF   80   6'9"
# 99   100         Andrew Wiggins   Warriors   SF   80   6'7"
#
#                        Build
# 0   2-Way Slashing Playmaker
# 1           Offensive Threat
# 2      2-Way Scoring Machine
# 3   2-Way Slashing Playmaker
# 4      2-Way Scoring Machine
# ..                       ...
# 95               Paint Beast
# 96   Glass-Cleaning Finisher
# 97         Inside-Out Scorer
# 98    Mid-Range Shot Creator
# 99                   Slasher
#
# [100 rows x 7 columns]

# %%
# Set Rank as index

rank.set_index('Rank', inplace=True)

display(rank)
# Out:
#                      Player       Team Pos.  OVR Height  \
# Rank
# 1              LeBron James     Lakers   SF   97   6'9"
# 2               Steph Curry   Warriors   PG   96   6'3"
# 3             Kawhi Leonard   Clippers   SF   96   6'7"
# 4     Giannis Antetokounmpo      Bucks   PF   96  6'11"
# 5              Kevin Durant       Nets   SF   96   6'10
# ...                     ...        ...  ...  ...    ...
# 96             Steven Adams   Pelicans    C   80  6'11"
# 97              Enes Kanter    Celtics    C   80  6'10"
# 98           Thaddeus Young      Bulls   PF   80   6'8"
# 99            Kyle Anderson  Grizzlies   SF   80   6'9"
# 100          Andrew Wiggins   Warriors   SF   80   6'7"
#
#                          Build
# Rank
# 1     2-Way Slashing Playmaker
# 2             Offensive Threat
# 3        2-Way Scoring Machine
# 4     2-Way Slashing Playmaker
# 5        2-Way Scoring Machine
# ...                        ...
# 96                 Paint Beast
# 97     Glass-Cleaning Finisher
# 98           Inside-Out Scorer
# 99      Mid-Range Shot Creator
# 100                    Slasher
#
# [100 rows x 6 columns]

# %%
# Teams with the most players in the NBA 2k21 Top 100

rank['Team'].value_counts().head()
# Out:
# Nets         7
# Pacers       5
# Grizzlies    5
# Nuggets      5
# Clippers     5
# Name: Team, dtype: int64

# %%
# Most common player build

rank['Build'].value_counts().idxmax()
# Out:
# 'Inside-Out Scorer'

# %%
# Plotting the Top 10 rated players

top10 = rank.head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=top10, x='Player', y='OVR')
plt.ylim(85,100)
# Out:
# (85.0, 100.0)
